# %% [markdown]
# # Projeto XML/NFE - Madruga

# %% [markdown]
# ## Fase inicial de prototipação

# %% [markdown]
# Nessa Fase a intenção é desenvolver um protótipo da funcionalidade operacional.
# As etapas desse protótipo contemplam:
# - leitura do arquivo XML
# - Formatar o XML para um dataframe
# - Formatar modelo genérico
# - Montar interface
# - Adicionar a interface filtro do Dataframe em todos os campos

# %%
import xmltodict
import os
import pandas as pd

# %%
values=[]     
os.chdir("xml")
xml_list = list()

for xml in os.listdir():
    xml_list.append(xml);

# %%
xml_list
# Out:
# ['NFe550000111432 41191004240670000136550010001114321689665805.xml',
#  'NFe550000124094 41191007295822000358550010001240941300554390.xml',
#  'NFe550000123792 41191007295822000358550010001237921762238625.xml',
#  'NFe550000032835 35191060642774000148550010000328351973074167.xml',
#  'NFe550000117378 42191002575973000184550010001173781016395907.xml']

# %%
nfe_list = []
for xml in xml_list:
    with open(xml) as fd:
        nfe = xmltodict.parse(fd.read())


    nfe_id = nfe['nfeProc']['NFe']['infNFe']['@Id'] # infNFe Id
    itens = nfe['nfeProc']['NFe']['infNFe']['det']

    print("NFe: ", nfe_id)
    print("NCM      |   Equipamento")

    for item in itens:
        prods = []
        for key in item['prod'].keys():
            prods.append(item['prod'][key])

        values.append(prods)
        prods.append(nfe_id)
        
    df = pd.DataFrame.from_records(values)
    col = list(item['prod'].keys())
    col.append('Nfe')
    df.columns = col
    df
# Out:
# NFe:  NFe41191004240670000136550010001114321689665805
# NCM      |   Equipamento
# NFe:  NFe41191007295822000358550010001240941300554390
# NCM      |   Equipamento
# NFe:  NFe41191007295822000358550010001237921762238625
# NCM      |   Equipamento
# NFe:  NFe35191060642774000148550010000328351973074167
# NCM      |   Equipamento
# NFe:  NFe42191002575973000184550010001173781016395907
# NCM      |   Equipamento

# %%
        #values.append([item['prod']['NCM'],  item['prod']['xProd']])
        #print(item.keys())
    #    for i in range(len(item)):
    #        values.append(item[i][0])
                
#print(values)
df = pd.DataFrame.from_records(values)
col = list(item['prod'].keys())
col.append('Nfe')
df.columns = col
df[['xProd','NCM','CFOP']]
df
# Out:
#      cProd            cEAN                                              xProd  \
# 0    20336   7899381797899                               FARBEN AGUARRAS 0.9L
# 1    20304   7899381687244                           FARBEN THINNER 5000 0.9L
# 2     4812   7891567174425                SAYERLACK VERNIZ POLIREX MOGNO 0.9L
# 3     4811   7891567174418                SAYERLACK VERNIZ POLIREX MOGNO 3.6L
# 4     8900   7891019172917              SPARLACK SELADORA BAL AC INCOLOR 3,6L
# 5    10812   7891574057322              SPARLACK VERNIZ NEUTREX MOGNO BR 3,6L
# 6    10810   7891019170210             SPARLACK VERNIZ NEUTREX IMBUIA BR 3,6L
